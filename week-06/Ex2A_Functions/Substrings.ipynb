# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
    for i in range (len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]

            print(f"Full name: {name}")
            print(f"First name:{first}")
            print(f"Last name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full name: John Doe
# First name:John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB 0inonen', 'Ken Penn ']

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Grace Flores
# First name:Grace
# Last name: Flores

# %%
parse_and_display(test_list[1])
# Out:
# Full name: JB 0inonen
# First name:JB
# Last name: 0inonen

# %%
parse_and_display(test_list[2])
# Out:
# Full name: Ken Penn
# First name:Ken
# Last name: Penn
# Full name: Ken Penn
# First name:Ken Penn
# Last name:

# %%
parse_and_display('Samia Omer')
# Out:
# Full name: Samia Omer
# First name:Samia
# Last name: Omer

# %%
def parse_and_display2(name):
    parts = name.split()

    if len(parts) == 1:
        print(f"Full name: {name}")
        print(f"First name: {parts[0]}")

    elif len(parts) == 2:
        print(f"Full name: {name}")
        print(f"First name: {parts[0]}")
        print(f"Last name: {parts[1]}")

    elif len(parts) == 3:
        print(f"Full name: {name}")
        print(f"First name: {parts[0]}")
        print(f"Middle name: {parts[1]}")
        print(f"Last name: {parts[2]}")

# %%
parse_and_display2('Lorde')
# Out:
# Full name: Lorde
# First name: Lorde

# %%
parse_and_display2('Billie Eilish')
# Out:
# Full name: Billie Eilish
# First name: Billie
# Last name: Eilish

# %%
parse_and_display2('Megan Thee Stallion')
# Out:
# Full name: Megan Thee Stallion
# First name: Megan
# Middle name: Thee
# Last name: Stallion
